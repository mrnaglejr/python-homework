# %%
# Import the pathlib and csv library
from pathlib import Path
import csv

#Set the file path
csvpath = Path('budget_data.csv')

#Initialize variable to hold salaries
date = []
profitloss = []
linenum = 0

# Open the input path as a file object
with open(csvpath, 'r') as csvfile:
    
    # Print the datatype of the file object
    print(type(csvfile))
    
    # Pass in the csv file to the csv.reader()function
    # (with ',' as the delmiter/separator) and return the csvreader object 
    csvreader = csv.reader(csvfile, delimiter=',')
    
    # Print the datatype of the csvreader
    print(type(csvreader))
    
    # Go to the next row from the start of the file
    # (which is often the first row/header) and iterate lin_num by 1
    header = next(csvreader)
    linenum += 1
    print(header)
    
    # Read each row of data after the header
    for row in csvreader:
        # Print the row
        print(row)
    
    print(csvfile)
# Out:
# <class '_io.TextIOWrapper'>
# <class '_csv.reader'>
# ['Date', 'Profit/Losses']
# ['Jan-2010', '867884']
# ['Feb-2010', '984655']
# ['Mar-2010', '322013']
# ['Apr-2010', '-69417']
# ['May-2010', '310503']
# ['Jun-2010', '522857']
# ['Jul-2010', '1033096']
# ['Aug-2010', '604885']
# ['Sep-2010', '-216386']
# ['Oct-2010', '477532']
# ['Nov-2010', '893810']
# ['Dec-2010', '-80353']
# ['Jan-2011', '779806']
# ['Feb-2011', '-335203']
# ['Mar-2011', '697845']
# ['Apr-2011', '793163']
# ['May-2011', '485070']
# ['Jun-2011', '584122']
# ['Jul-2011', '62729']
# ['Aug-2011', '668179']
# ['Sep-2011', '899906']
# ['Oct-2011', '834719']
# ['Nov-2011', '132003']
# ['Dec-2011', '309978']
# ['Jan-2012', '-755566']
# ['Feb-2012', '1170593']
# ['Mar-2012', '252788']
# ['Apr-2012', '1151518']
# ['May-2012', '817256']
# ['Jun-2012', '570757']
# ['Jul-2012', '506702']
# ['Aug-2012', '-1022534']
# ['Sep-2012', '475062']
# ['Oct-2012', '779976']
# ['Nov-2012', '144175']
# ['Dec-2012', '542494']
# ...

# %%
with open(csvpath, 'r') as file:
    
    csvreader =csv.reader(file, delimiter=',')
    
    header = next(csvreader)
    linenum += 1
    
    for row in csvreader:
        profit = int(row[1])
        months = row[0]
        profitloss.append(profit)

        
print(profitloss.index(867884, 1, -1))
# Out:
# 86

# %%
from pathlib import Path
import csv
csvpath = Path('budget_data.csv')

profits = []
line_num = 0
max_profit = 0
min_profit = 0
total_profit = 0
count_profit = 0
date_count = 0


with open(csvpath, 'r') as csvfile:
    print(type(csvfile))
    csvreader = csv.reader(csvfile, delimiter=',')
    print(type(csvreader))
    header = next(csvreader)
    line_num += 1
    print(f"{header}<---- HEADER")
    for row in csvreader:
        print(row)
        profit = int(row[1])
        profits.append(profit)
      
    
        

for profit in profits:
    total_profit += profit
    count_profit += 1
    
    if min_profit == 0:
        min_profit = profit
    elif profit > max_profit:
        max_profit = profit
    elif profit < min_profit:
        min_profit = profit
    

    
print(max_profit, min_profit, total_profit)

header = ["Max_Profit", "Min_Profit", "Total_Profit"]
metrics = [max_profit, min_profit, total_profit]

output_path = Path('budget_data_output.csv')
with open(output_path, 'w') as csvfile:
    csvwriter = csv.writer(csvfile, delimiter=',')
    csvwriter.writerow(header)
    csvwriter.writerow(metrics)
# Out:
# <class '_io.TextIOWrapper'>
# <class '_csv.reader'>
# ['Date', 'Profit/Losses']<---- HEADER
# ['Jan-2010', '867884']
# ['Feb-2010', '984655']
# ['Mar-2010', '322013']
# ['Apr-2010', '-69417']
# ['May-2010', '310503']
# ['Jun-2010', '522857']
# ['Jul-2010', '1033096']
# ['Aug-2010', '604885']
# ['Sep-2010', '-216386']
# ['Oct-2010', '477532']
# ['Nov-2010', '893810']
# ['Dec-2010', '-80353']
# ['Jan-2011', '779806']
# ['Feb-2011', '-335203']
# ['Mar-2011', '697845']
# ['Apr-2011', '793163']
# ['May-2011', '485070']
# ['Jun-2011', '584122']
# ['Jul-2011', '62729']
# ['Aug-2011', '668179']
# ['Sep-2011', '899906']
# ['Oct-2011', '834719']
# ['Nov-2011', '132003']
# ['Dec-2011', '309978']
# ['Jan-2012', '-755566']
# ['Feb-2012', '1170593']
# ['Mar-2012', '252788']
# ['Apr-2012', '1151518']
# ['May-2012', '817256']
# ['Jun-2012', '570757']
# ['Jul-2012', '506702']
# ['Aug-2012', '-1022534']
# ['Sep-2012', '475062']
# ['Oct-2012', '779976']
# ['Nov-2012', '144175']
# ...

# %%
#----------
# Total Months - 86
# Total Profit/Loss = 383825578
# Total Max Profit = 1170593
# Total Min Profit = -1196225
